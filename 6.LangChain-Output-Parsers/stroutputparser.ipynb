# %% [markdown]
# <a href="https://colab.research.google.com/github/Yes-Amrit/LangChain-Models/blob/main/6.LangChain-Output-Parsers/stroutputparser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the necessary libraries
# !pip install -q langchain-huggingface huggingface_hub python-dotenv

# %%
import os
from google.colab import userdata

# Pull the token from Colab Secrets
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# %%
from google.colab import userdata
import os

try:
    token = userdata.get('HUGGINGFACEHUB_API_TOKEN')
    if token:
        print(f"Token found! Starts with: {token[:5]}...")
        os.environ["HUGGINGFACEHUB_API_TOKEN"] = token
    else:
        print("Token is empty. Check your Secrets tab.")
except Exception as e:
    print(f"Error accessing secret: {e}")
# Out:
# Token found! Starts with: "hf_s...

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from google.colab import userdata
import os

# Get token from secrets
sec_token = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# Initialize LLM with the token explicitly
llm = HuggingFaceEndpoint(
    repo_id='meta-llama/Meta-Llama-3-8B-Instruct',
    task='text-generation',
    max_new_tokens=1024,
    huggingfacehub_api_token=sec_token  # Pass it here directly
)

model = ChatHuggingFace(llm=llm)

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from google.colab import userdata
import os

# Setup Token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# Initialize Model (Llama 3 as we discussed)
llm = HuggingFaceEndpoint(
    repo_id='meta-llama/Meta-Llama-3-8B-Instruct',
    task='text-generation',
    max_new_tokens=1024
)
model = ChatHuggingFace(llm=llm)

# Your Prompt Logic
template1 = PromptTemplate(template='Write a detailed report on {topic}', input_variables=['topic'])
prompt1 = template1.format(topic='black hole')

# Run and Print
result = model.invoke(prompt1)
print(result.content)
# Out:
# **Report on Black Holes**
#
# **Introduction**
#
# Black holes are among the most fascinating and mysterious objects in the universe. They are regions of spacetime where the gravitational pull is so strong that nothing, including light, can escape from them. The concept of black holes has been studied extensively in astrophysics and cosmology, and our understanding of these phenomena has evolved significantly over the past few decades. This report provides a comprehensive overview of black holes, including their formation, characteristics, and current understanding of their behavior.
#
# **Formation of Black Holes**
#
# ...
